# %%
#문자열 연결 연산자
print("안녕" + "하세요")
# Out:
# 안녕하세요

# %%
#인덱싱
print("안녕하세요"[0])
# Out:
# 안

# %%
#슬라이싱
print("12345"[:3])
# Out:
# 123

# %%
#문자열 길이
print(len("안녕하세요"))
# Out:
# 5

# %%
# input()은 사용자가 입력한걸 모두 str로 받는다
str = input("숫자를 입력하세요:")
type(str)
# Out:
# str

# %%
#format 함수 - 소수점 자르기
a = 52.377
b = "{:0.1f}".format(a)

b
# Out:
# '52.4'

# %%
#format 함수 기호 추가
b = 42.345
a = "{:+0.1f}".format(-b)

a
# Out:
# '-42.3'

# %%
#대소문자 바꾸기
a= "HELLO WORLD"
b= "hello world"

print(a.lower())
print(b.upper())
# Out:
# hello world
# HELLO WORLD

# %%
#문자열 공백 삭제
a = "   hello world   "
a
# Out:
# '   hello world   '

# %%
a.strip()
# Out:
# 'hello world'

# %%
a.lstrip()
# Out:
# 'hello world   '

# %%
#문자열 구성 파악하기 - is~~~함수
"abc123".isalnum()
# Out:
# True

# %%
#문자열내에서 찾기
"avcdsaef".rfind("a")
# Out:
# 5

# %%
"안녕하세요안녕하세용가리".find("하세용")
# Out:
# 7

# %%
#문자열과 in 연산자 - 문자열 내부에 어떤 문자열있는지 확인
"잘" in "잘자"
# Out:
# True
