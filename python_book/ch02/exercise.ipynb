# %%
# 구의 부피와 겉넓이 구하기
a= int(input("구의 반지름을 이력해주세요 : "))
pi = 3.14
print(f"= 구의 부피는 {4/3*pi*(a**3)}입니다.")
print(f"= 구의 겉넓이는 {4*pi*(a**2)}입니다.")
# Out:
# = 구의 부피는 267.94666666666666입니다.
# = 구의 겉넓이는 200.96입니다.

# %%
a = int(input("밑변의 길이를 입력해주세요 : "))
b = int(input("높이의 길이를 입력해주세요 : "))

bit = ((a**2) + (b**2))**(0.5)
bit
# Out:
# 5.0
