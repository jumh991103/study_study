# %%
import pandas as pd

tup_data=('영인','2010-05-01','여',True)
sr = pd.Series(tup_data, index = ['이름', '생년월일', '성별', '학생여부'])
print(sr)
# Out:
# 이름              영인
# 생년월일    2010-05-01
# 성별               여
# 학생여부          True
# dtype: object

# %%
sr[['이름','생년월일']]
# Out:
# 이름              영인
# 생년월일    2010-05-01
# dtype: object
